# %% [markdown]
# # Convo Capsule: Training on Google Colab
#
# Use this notebook to train your model using **Google Drive** storage and **Free T4 GPUs**.
#
# ### Steps:
# 1. Upload your code (`train.py`, `model.py`, etc.) to a folder in Drive (e.g., `ConvoCapsule`).
# 2. Upload your dataset to Drive (or download it directly here).
# 3. Run these cells.

# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# 2. Check GPU
# !nvidia-smi

# %%
# 3. Navigate to your project folder
import os
# Change this to where you uploaded your python files
# %cd /content/drive/MyDrive/ConvoCapsule

# %%
# 4. Install Dependencies
# !pip install torch torchaudio scipy numpy

# %%
# 5. Prepare Dataset (If needed)
# If you have the wav files in Drive, map them:
# !python prepare_voxceleb.py --data_root "/content/drive/MyDrive/VoxCeleb/wav" --output "drive_train_list.txt"

# %%
# 6. Run Training
# Ensure n_classes matches your dataset
# !python train.py --data_root "/content/drive/MyDrive/VoxCeleb/wav" --train_list "drive_train_list.txt" --n_classes 100 --epochs 20
